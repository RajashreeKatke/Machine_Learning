# %% [markdown]
# ## Problem Statements based on Cars93 Data Set

# %% [markdown]
# ### 1. Find out car having highest Mileage in city

# %%
import pandas as pd
A = pd.read_csv("Desktop/Data Science/Data Sets/Cars93.csv")

# %%
A.head()
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
# 3   4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4   5          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0           31                None  ...          5    177        102     68
# 1           25  Driver & Passenger  ...          5    195        115     71
# 2           26         Driver only  ...          5    180        102     67
# 3           26                 NaN  ...          6    193        106     70
# 4           30         Driver only  ...          4    186        109     69
#
# ...

# %%
A["MPG.city"].max()
# Out:
# 46

# %%
A[["Make","MPG.city"]][(A["MPG.city"]==46)]
# Out:
#          Make  MPG.city
# 38  Geo Metro        46

# %% [markdown]
# ### 2. Find out Models of cars which are having Price between 17 and 25

# %%
A[["Model","Price"]][(A.Price>17)&(A.Price<25)]
# Out:
#              Model  Price
# 6          LeSabre   20.8
# 7       Roadmaster   23.7
# 17         Caprice   18.8
# 19        Concorde   18.4
# 25         Caravan   19.0
# 29          Vision   19.3
# 35        Aerostar   19.9
# 36          Taurus   20.2
# 37  Crown_Victoria   20.9
# 40         Prelude   19.8
# 42          Accord   17.5
# 55             MPV   19.1
# 65           Quest   19.1
# 66          Maxima   21.5
# 69      Silhouette   19.5
# 70    Eighty-Eight   20.7
# 74        Firebird   17.7
# 75      Grand_Prix   18.5
# 76      Bonneville   24.4
# 81          Legacy   19.5
# 84          Celica   18.4
# 85           Camry   18.2
# 86          Previa   22.7
# 88         Eurovan   19.7
# 89          Passat   20.0
# 90         Corrado   23.3
# 91             240   22.7

# %% [markdown]
# ### 3. Find out top 7 most fuel economic cars for highway

# %%
A.sort_values(by=["MPG.highway"],ascending=False,inplace=True)

# %%
A
# Out:
#     id Manufacturer     Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 38  39          Geo     Metro    Small        6.7    8.4       10.0        46
# 41  42        Honda     Civic    Small        8.4   12.1       15.8        42
# 82  83       Suzuki     Swift    Small        7.3    8.6       10.0        39
# 72  73      Pontiac    LeMans    Small        8.2    9.0        9.9        31
# 78  79       Saturn        SL    Small        9.2   11.1       12.9        28
# ..  ..          ...       ...      ...        ...    ...        ...       ...
# 47  48     Infiniti       Q45  Midsize       45.4   47.9       50.4        17
# 88  89   Volkswagen   Eurovan      Van       16.6   19.7       22.7        17
# 25  26        Dodge   Caravan      Van       13.6   19.0       24.4        17
# 16  17    Chevrolet     Astro      Van       14.7   16.6       18.6        15
# 35  36         Ford  Aerostar      Van       14.5   19.9       25.3        15
#
# ...

# %%
A[["Make","MPG.highway"]].head(7)
# Out:
#               Make  MPG.highway
# 38       Geo Metro           50
# 41     Honda Civic           46
# 82    Suzuki Swift           43
# 72  Pontiac LeMans           41
# 78       Saturn SL           38
# 79    Subaru Justy           37
# 52       Mazda 323           37

# %% [markdown]
# ### 4. Find out Models of cars having no AirBags and which are of compact type whose price is below 20.

# %%
A[["Model","AirBags","Type","Price"]][(A.AirBags=="None")&(A.Type=="Compact")&(A.Price<20)]
# Out:
#        Model AirBags     Type  Price
# 11  Cavalier    None  Compact   13.4
# 67   Achieva    None  Compact   13.5
# 73   Sunbird    None  Compact   11.1
# 32     Tempo    None  Compact   11.3

# %% [markdown]
# ### 5. Find out top 7 most fuel economic cars for city, show results in sorted manner based on Horsepower.

# %%
A.sort_values(by=["MPG.city"],ascending=False,inplace=True)

# %%
A
# Out:
#     id Manufacturer       Model     Type  Min.Price  Price  Max.Price  \
# 38  39          Geo       Metro    Small        6.7    8.4       10.0
# 41  42        Honda       Civic    Small        8.4   12.1       15.8
# 82  83       Suzuki       Swift    Small        7.3    8.6       10.0
# 79  80       Subaru       Justy    Small        7.3    8.4        9.5
# 83  84       Toyota      Tercel    Small        7.8    9.8       11.8
# ..  ..          ...         ...      ...        ...    ...        ...
# 9   10     Cadillac     DeVille    Large       33.0   34.7       36.3
# 7    8        Buick  Roadmaster    Large       22.6   23.7       24.9
# 10  11     Cadillac     Seville  Midsize       37.5   40.1       42.7
# 16  17    Chevrolet       Astro      Van       14.7   16.6       18.6
# 35  36         Ford    Aerostar      Van       14.5   19.9       25.3
#
#     MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# ...

# %%
A[["Make","MPG.city","Horsepower"]].head(7)
# Out:
#               Make  MPG.city  Horsepower
# 38       Geo Metro        46          55
# 41     Honda Civic        42         102
# 82    Suzuki Swift        39          70
# 79    Subaru Justy        33          73
# 83   Toyota Tercel        32          82
# 72  Pontiac LeMans        31          74
# 30    Ford Festiva        31          63

# %%
B = A[["Make","MPG.city","Horsepower"]].head(7)

# %%
B
# Out:
#               Make  MPG.city  Horsepower
# 38       Geo Metro        46          55
# 41     Honda Civic        42         102
# 82    Suzuki Swift        39          70
# 79    Subaru Justy        33          73
# 83   Toyota Tercel        32          82
# 72  Pontiac LeMans        31          74
# 30    Ford Festiva        31          63

# %%
B.sort_values(by=["Horsepower"],ascending=True)
# Out:
#               Make  MPG.city  Horsepower
# 38       Geo Metro        46          55
# 30    Ford Festiva        31          63
# 82    Suzuki Swift        39          70
# 79    Subaru Justy        33          73
# 72  Pontiac LeMans        31          74
# 83   Toyota Tercel        32          82
# 41     Honda Civic        42         102

# %% [markdown]
# ### 6. Find out Cars having mileage of more than 15 miles in city

# %%
A[["Make","MPG.city"]][(A["MPG.city"]>15)]
# Out:
#                    Make  MPG.city
# 38            Geo Metro        46
# 41          Honda Civic        42
# 82         Suzuki Swift        39
# 79         Subaru Justy        33
# 83        Toyota Tercel        32
# ..                  ...       ...
# 50  Lincoln Continental        17
# 17    Chevrolet Caprice        17
# 9      Cadillac DeVille        16
# 7      Buick Roadmaster        16
# 10     Cadillac Seville        16
#
# [91 rows x 2 columns]

# %% [markdown]
# ### 7. Find out Cars with US based origin

# %%
A[["Make","Origin"]][(A.Origin=="USA")]
# Out:
#                         Make Origin
# 72            Pontiac LeMans    USA
# 30              Ford Festiva    USA
# 28              Eagle Summit    USA
# 22                Dodge Colt    USA
# 78                 Saturn SL    USA
# 11        Chevrolet Cavalier    USA
# 12         Chevrolet Corsica    USA
# 67        Oldsmobile Achieva    USA
# 34                Ford Probe    USA
# 31               Ford Escort    USA
# 59             Mercury Capri    USA
# 20          Chrysler LeBaron    USA
# 23              Dodge Shadow    USA
# 71            Plymouth Laser    USA
# 73           Pontiac Sunbird    USA
# 68  Oldsmobile Cutlass_Ciera    USA
# 32                Ford Tempo    USA
# 24              Dodge Spirit    USA
# 33              Ford Mustang    USA
# 5              Buick Century    USA
# 26             Dodge Dynasty    USA
# 14          Chevrolet Lumina    USA
# 36               Ford Taurus    USA
# 19         Chrylser Concorde    USA
# 21         Chrysler Imperial    USA
# ...

# %% [markdown]
# ### 8. Find out Cars with no airbags and which are compact in type, from the output retrieve only Model, Mileage in city, Type, Airbags

# %%
A[(A.AirBags=="None")&(A.Type=="Compact")]
# Out:
#     id Manufacturer     Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 11  12    Chevrolet  Cavalier  Compact        8.5   13.4       18.3        25
# 67  68   Oldsmobile   Achieva  Compact       13.0   13.5       14.0        24
# 73  74      Pontiac   Sunbird  Compact        9.4   11.1       12.8        23
# 32  33         Ford     Tempo  Compact       10.4   11.3       12.2        22
# 89  90   Volkswagen    Passat  Compact       17.6   20.0       22.4        21
#
#     MPG.highway AirBags  ... Passengers Length  Wheelbase  Width  Turn.circle  \
# 11           36    None  ...          5    182        101     66           38
# 67           31    None  ...          5    188        103     67           39
# 73           31    None  ...          5    181        101     66           39
# 32           27    None  ...          5    177        100     68           39
# 89           30    None  ...          5    180        103     67           35
#
# ...

# %%
C = A[(A.AirBags=="None")&(A.Type=="Compact")]
C
# Out:
#     id Manufacturer     Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 11  12    Chevrolet  Cavalier  Compact        8.5   13.4       18.3        25
# 67  68   Oldsmobile   Achieva  Compact       13.0   13.5       14.0        24
# 73  74      Pontiac   Sunbird  Compact        9.4   11.1       12.8        23
# 32  33         Ford     Tempo  Compact       10.4   11.3       12.2        22
# 89  90   Volkswagen    Passat  Compact       17.6   20.0       22.4        21
#
#     MPG.highway AirBags  ... Passengers Length  Wheelbase  Width  Turn.circle  \
# 11           36    None  ...          5    182        101     66           38
# 67           31    None  ...          5    188        103     67           39
# 73           31    None  ...          5    181        101     66           39
# 32           27    None  ...          5    177        100     68           39
# 89           30    None  ...          5    180        103     67           35
#
# ...

# %%
C[["Model","MPG.city","Type","AirBags"]]
# Out:
#        Model  MPG.city     Type AirBags
# 11  Cavalier        25  Compact    None
# 67   Achieva        24  Compact    None
# 73   Sunbird        23  Compact    None
# 32     Tempo        22  Compact    None
# 89    Passat        21  Compact    None

# %% [markdown]
# ### 9. Find out cars with Mileage in city more than 15 which are compact in type.

# %%
A[(A["MPG.city"]>15)&(A.Type=="Compact")]
# Out:
#     id   Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 54  55          Mazda       626  Compact       14.3   16.5       18.7
# 11  12      Chevrolet  Cavalier  Compact        8.5   13.4       18.3
# 12  13      Chevrolet   Corsica  Compact       11.4   11.4       11.4
# 67  68     Oldsmobile   Achieva  Compact       13.0   13.5       14.0
# 64  65         Nissan    Altima  Compact       13.0   15.7       18.3
# 42  43          Honda    Accord  Compact       13.8   17.5       21.2
# 20  21       Chrysler   LeBaron  Compact       14.5   15.8       17.1
# 81  82         Subaru    Legacy  Compact       16.3   19.5       22.7
# 73  74        Pontiac   Sunbird  Compact        9.4   11.1       12.8
# 32  33           Ford     Tempo  Compact       10.4   11.3       12.2
# 24  25          Dodge    Spirit  Compact       11.9   13.3       14.7
# 89  90     Volkswagen    Passat  Compact       17.6   20.0       22.4
# ...

# %%
A[["Make","MPG.city","Type"]][(A["MPG.city"]>15)&(A.Type=="Compact")]
# Out:
#                   Make  MPG.city     Type
# 54           Mazda 626        26  Compact
# 11  Chevrolet Cavalier        25  Compact
# 12   Chevrolet Corsica        25  Compact
# 67  Oldsmobile Achieva        24  Compact
# 64       Nissan Altima        24  Compact
# 42        Honda Accord        24  Compact
# 20    Chrysler LeBaron        23  Compact
# 81       Subaru Legacy        23  Compact
# 73     Pontiac Sunbird        23  Compact
# 32          Ford Tempo        22  Compact
# 24        Dodge Spirit        22  Compact
# 89   Volkswagen Passat        21  Compact
# 91           Volvo 240        21  Compact
# 57  Mercedes-Benz 190E        20  Compact
# 2              Audi 90        20  Compact
# 77            Saab 900        20  Compact

# %% [markdown]
# ## Problem Statements based on Hitters Dataset

# %% [markdown]
# ### Find of people who have batted for more than 400 matches

# %%
H = pd.read_csv("Desktop/Data Science/Data Sets/hitters.csv")

# %%
H
# Out:
#                  Name  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0       Andy Allanson    293    66      1    30   29     14      1     293
# 1          Alan Ashby    315    81      7    24   38     39     14    3449
# 2         Alvin Davis    479   130     18    66   72     76      3    1624
# 3        Andre Dawson    496   141     20    65   78     37     11    5628
# 4    Andres Galarraga    321    87     10    39   42     30      2     396
# ..                ...    ...   ...    ...   ...  ...    ...    ...     ...
# 317      Willie McGee    497   127      7    65   48     37      5    2703
# 318   Willie Randolph    492   136      5    76   50     94     12    5511
# 319    Wayne Tolleson    475   126      3    61   43     52      6    1700
# 320     Willie Upshaw    573   144      9    85   60     78      8    3198
# 321     Willie Wilson    631   170      9    77   44     31     11    4908
#
# ...

# %%
H[["Name","AtBat"]][(H.AtBat>400)]
# Out:
#                 Name  AtBat
# 2        Alvin Davis    479
# 3       Andre Dawson    496
# 5    Alfredo Griffin    594
# 9     Andre Thornton    401
# 10     Alan Trammell    574
# ..               ...    ...
# 317     Willie McGee    497
# 318  Willie Randolph    492
# 319   Wayne Tolleson    475
# 320    Willie Upshaw    573
# 321    Willie Wilson    631
#
# [151 rows x 2 columns]

# %% [markdown]
# ### Find out the name of the player who has hit max home runs

# %%
H.HmRun.max()
# Out:
# 40

# %%
H[["Name","HmRun"]][(H.HmRun==40)]
# Out:
#                Name  HmRun
# 136  Jesse Barfield     40

# %% [markdown]
# ### Find out league wise total number of players

# %%
H.groupby(by=["League"])["Name"].count()
# Out:
# League
# A    175
# N    147
# Name: Name, dtype: int64

# %% [markdown]
# ### Find out division wise total amount of salary invested

# %%
H.groupby(by=["Division"])["Salary"].sum()
# Out:
# Division
# E    80531.006
# W    60417.501
# Name: Salary, dtype: float64

# %% [markdown]
# ### Find out five most senior players

# %%
H.sort_values(by=["Years"],ascending=False,inplace=True)

# %%
H
# Out:
#                 Name  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 236        Pete Rose    237    52      0    15   25     30     24   14053
# 302       Tony Perez    200    51      2    14   29     25     23    9778
# 121    Graig Nettles    354    77     16    36   55     41     20    8716
# 249   Reggie Jackson    419   101     18    65   58     92     20    9528
# 306      Ted Simmons    127    32      4    14   25     12     19    8396
# ..               ...    ...   ...    ...   ...  ...    ...    ...     ...
# 197      Luis Rivera    166    34      0    20   13     17      1     166
# 295    Terry Kennedy     19     4      1     2    3      1      1      19
# 233  Pete Incaviglia    540   135     30    82   88     55      1     540
# 201     Mike Aldrete    216    54      2    27   25     33      1     216
# 0      Andy Allanson    293    66      1    30   29     14      1     293
#
#      CHits  ...  CRuns  CRBI  CWalks  League Division PutOuts  Assists  \
# ...

# %%
H[["Name","Years"]].head()
# Out:
#                Name  Years
# 236       Pete Rose     24
# 302      Tony Perez     23
# 121   Graig Nettles     20
# 249  Reggie Jackson     20
# 306     Ted Simmons     19
